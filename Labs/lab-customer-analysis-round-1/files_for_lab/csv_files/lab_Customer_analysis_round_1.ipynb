# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Read the three files into python as dataframes.

# %%
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %% [markdown]
# #### Show the DataFrame's shape.

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %% [markdown]
# #### Standardize header names and Rearrange the columns in the dataframe as needed.

# %%
cols = []
for column in range(len(file1.columns)):
    cols.append(file1.columns[column].upper())
file1.columns = cols

# %%
cols = []
for column in range(len(file2.columns)):
    cols.append(file2.columns[column].upper())
file2.columns = cols

# %%
cols = []
for column in range(len(file3.columns)):
    cols.append(file3.columns[column].upper())
file3.columns = cols

# %%
file1 = file1.rename(columns={'ST':'STATE'})
file2 = file2.rename(columns={'ST':'STATE'})

# %%
file1=file1[['CUSTOMER', 'STATE', 'CUSTOMER LIFETIME VALUE', 'EDUCATION', 'GENDER',
       'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
       'POLICY TYPE', 'TOTAL CLAIM AMOUNT', 'VEHICLE CLASS']]

# %%
file2=file2[['CUSTOMER', 'STATE', 'CUSTOMER LIFETIME VALUE', 'EDUCATION', 'GENDER',
       'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
       'POLICY TYPE', 'TOTAL CLAIM AMOUNT', 'VEHICLE CLASS']]

# %%
file1.columns
# Out:
# Index(['CUSTOMER', 'STATE', 'CUSTOMER LIFETIME VALUE', 'EDUCATION', 'GENDER',
#        'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
#        'POLICY TYPE', 'TOTAL CLAIM AMOUNT', 'VEHICLE CLASS'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['CUSTOMER', 'STATE', 'CUSTOMER LIFETIME VALUE', 'EDUCATION', 'GENDER',
#        'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
#        'POLICY TYPE', 'TOTAL CLAIM AMOUNT', 'VEHICLE CLASS'],
#       dtype='object')

# %%
file3.columns
# Out:
# Index(['CUSTOMER', 'STATE', 'CUSTOMER LIFETIME VALUE', 'EDUCATION', 'GENDER',
#        'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
#        'POLICY TYPE', 'TOTAL CLAIM AMOUNT', 'VEHICLE CLASS'],
#       dtype='object')

# %% [markdown]
# #### Concatenate the three dataframes

# %%
data = pd.concat([file1,file2,file3])
data
# Out:
#      CUSTOMER       STATE CUSTOMER LIFETIME VALUE             EDUCATION  \
# 0     RB50392  Washington                     NaN                Master
# 1     QZ44356     Arizona              697953.59%              Bachelor
# 2     AI49188      Nevada             1288743.17%              Bachelor
# 3     WW63253  California              764586.18%              Bachelor
# 4     GA49547  Washington              536307.65%  High School or Below
# ...       ...         ...                     ...                   ...
# 7065  LA72316  California             23405.98798              Bachelor
# 7066  PK87824  California             3096.511217               College
# 7067  TD14365  California             8163.890428              Bachelor
# 7068  UP19263  California             7524.442436               College
# 7069  Y167826  California             2611.836866               College
#
#      GENDER   INCOME  MONTHLY PREMIUM AUTO NUMBER OF OPEN COMPLAINTS  \
# ...

# %% [markdown]
# #### Which columns are numerical?

# %%
data.select_dtypes('number')
# Out:
#        INCOME  MONTHLY PREMIUM AUTO  TOTAL CLAIM AMOUNT
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %% [markdown]
# The columns that are numerical are Income, Monthly Premium Auto and Total Claim Amount

# %% [markdown]
# #### Which columns are categorical?

# %%
data.select_dtypes('object')
# Out:
#      CUSTOMER       STATE CUSTOMER LIFETIME VALUE             EDUCATION  \
# 0     RB50392  Washington                     NaN                Master
# 1     QZ44356     Arizona              697953.59%              Bachelor
# 2     AI49188      Nevada             1288743.17%              Bachelor
# 3     WW63253  California              764586.18%              Bachelor
# 4     GA49547  Washington              536307.65%  High School or Below
# ...       ...         ...                     ...                   ...
# 7065  LA72316  California             23405.98798              Bachelor
# 7066  PK87824  California             3096.511217               College
# 7067  TD14365  California             8163.890428              Bachelor
# 7068  UP19263  California             7524.442436               College
# 7069  Y167826  California             2611.836866               College
#
#      GENDER NUMBER OF OPEN COMPLAINTS     POLICY TYPE  VEHICLE CLASS
# ...

# %% [markdown]
# The columns that are numerical are Customer, State, Customer Lifetime Value, Education, Gender, Number of Open Complaints, Policy Type and Vehicle Class

# %% [markdown]
# #### Understand the meaning of all columns

# %%
data
# Out:
#      CUSTOMER       STATE CUSTOMER LIFETIME VALUE             EDUCATION  \
# 0     RB50392  Washington                     NaN                Master
# 1     QZ44356     Arizona              697953.59%              Bachelor
# 2     AI49188      Nevada             1288743.17%              Bachelor
# 3     WW63253  California              764586.18%              Bachelor
# 4     GA49547  Washington              536307.65%  High School or Below
# ...       ...         ...                     ...                   ...
# 7065  LA72316  California             23405.98798              Bachelor
# 7066  PK87824  California             3096.511217               College
# 7067  TD14365  California             8163.890428              Bachelor
# 7068  UP19263  California             7524.442436               College
# 7069  Y167826  California             2611.836866               College
#
#      GENDER   INCOME  MONTHLY PREMIUM AUTO NUMBER OF OPEN COMPLAINTS  \
# ...

# %%
data.dtypes
# Out:
# CUSTOMER                      object
# STATE                         object
# CUSTOMER LIFETIME VALUE       object
# EDUCATION                     object
# GENDER                        object
# INCOME                       float64
# MONTHLY PREMIUM AUTO         float64
# NUMBER OF OPEN COMPLAINTS     object
# POLICY TYPE                   object
# TOTAL CLAIM AMOUNT           float64
# VEHICLE CLASS                 object
# dtype: object

# %% [markdown]
# #### Delete the column education and the number of open complaints from the dataframe.

# %%
data.drop(['EDUCATION','NUMBER OF OPEN COMPLAINTS'],axis=1,inplace=True)

# %% [markdown]
# #### Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %%
data
# Out:
#      CUSTOMER       STATE CUSTOMER LIFETIME VALUE GENDER   INCOME  \
# 0     RB50392  Washington                     NaN    NaN      0.0
# 1     QZ44356     Arizona              697953.59%      F      0.0
# 2     AI49188      Nevada             1288743.17%      F  48767.0
# 3     WW63253  California              764586.18%      M      0.0
# 4     GA49547  Washington              536307.65%      M  36357.0
# ...       ...         ...                     ...    ...      ...
# 7065  LA72316  California             23405.98798      M  71941.0
# 7066  PK87824  California             3096.511217      F  21604.0
# 7067  TD14365  California             8163.890428      M      0.0
# 7068  UP19263  California             7524.442436      M  21941.0
# 7069  Y167826  California             2611.836866      M      0.0
#
#       MONTHLY PREMIUM AUTO     POLICY TYPE  TOTAL CLAIM AMOUNT  VEHICLE CLASS
# 0                   1000.0   Personal Auto            2.704934  Four-Door Car
# ...

# %%
data['CUSTOMER LIFETIME VALUE']=data['CUSTOMER LIFETIME VALUE'].astype(str).str.replace('%',"").astype(float) / 100

# %%
#list(map(lambda x: str(x).replace("%",""),data['customer_lifetime_value']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0m/d3zbckcj1zd772z7m1w0_xgc0000gn/T/ipykernel_97617/575271820.py in <module>
# ----> 1 astype()
#
# NameError: name 'astype' is not defined

# %% [markdown]
# #### Check for duplicate rows in the data and remove if any.

# %%
data.drop_duplicates()
# Out:
#      CUSTOMER       STATE  CUSTOMER LIFETIME VALUE GENDER   INCOME  \
# 0     RB50392  Washington                      NaN    NaN      0.0
# 1     QZ44356     Arizona              6979.535900      F      0.0
# 2     AI49188      Nevada             12887.431700      F  48767.0
# 3     WW63253  California              7645.861800      M      0.0
# 4     GA49547  Washington              5363.076500      M  36357.0
# ...       ...         ...                      ...    ...      ...
# 7065  LA72316  California               234.059880      M  71941.0
# 7066  PK87824  California                30.965112      F  21604.0
# 7067  TD14365  California                81.638904      M      0.0
# 7068  UP19263  California                75.244424      M  21941.0
# 7069  Y167826  California                26.118369      M      0.0
#
#       MONTHLY PREMIUM AUTO     POLICY TYPE  TOTAL CLAIM AMOUNT  VEHICLE CLASS
# 0                   1000.0   Personal Auto            2.704934  Four-Door Car
# ...

# %% [markdown]
# #### Filter out the data for customers who have an income of 0 or less.

# %%
data[data['INCOME'] <= 0]
# Out:
#      CUSTOMER       STATE  CUSTOMER LIFETIME VALUE GENDER  INCOME  \
# 0     RB50392  Washington                      NaN    NaN     0.0
# 1     QZ44356     Arizona              6979.535900      F     0.0
# 3     WW63253  California              7645.861800      M     0.0
# 7     CF85061     Arizona              7216.100300      M     0.0
# 10    SX51350  California              4738.992000      M     0.0
# ...       ...         ...                      ...    ...     ...
# 7059  WZ45103  California                56.780502      F     0.0
# 7061  RX91025  California               198.722620      M     0.0
# 7062  AC13887  California                46.289953      M     0.0
# 7067  TD14365  California                81.638904      M     0.0
# 7069  Y167826  California                26.118369      M     0.0
#
#       MONTHLY PREMIUM AUTO     POLICY TYPE  TOTAL CLAIM AMOUNT  VEHICLE CLASS
# 0                   1000.0   Personal Auto            2.704934  Four-Door Car
# ...
